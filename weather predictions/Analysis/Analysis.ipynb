# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets

# %%
data=pd.read_csv(r'C:\Users\USER\Desktop\WP\weather predictions\cleaning and preprocing\weatherml.csv')

# %%
sns.barplot (x=data['year'],y=data['Precip Type'],data=data,estimator=sum)
# Out:
# <Axes: xlabel='year', ylabel='Precip Type'>

# %%
sns.barplot (x=data['year'],y=data['Humidity'],data=data,estimator=sum)
# Out:
# <Axes: xlabel='year', ylabel='Humidity'>

# %%
sns.lineplot(x=data['Precip Type'],y=data['year'])
# Out:
# <Axes: xlabel='Precip Type', ylabel='year'>

# %%
sns.lineplot(x=data['year'],y=data['Humidity'])
# Out:
# <Axes: xlabel='year', ylabel='Humidity'>

# %%
sns.scatterplot(x=data['Precip Type'],y=data['year'])
# Out:
# <Axes: xlabel='Precip Type', ylabel='year'>

# %%
sns.histplot(x=data['year'],y=data['Humidity'])
# Out:
# <Axes: xlabel='year', ylabel='Humidity'>

# %%
rain=data[data['Precip Type']=='rain']

# %%
rain
# Out:
#               Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0       Partly Cloudy        rain         9.472222                  7.388889
# 1       Partly Cloudy        rain         9.355556                  7.227778
# 2       Mostly Cloudy        rain         9.377778                  9.377778
# 3       Partly Cloudy        rain         8.288889                  5.944444
# 4       Mostly Cloudy        rain         8.755556                  6.977778
# ...               ...         ...              ...                       ...
# 188531  Partly Cloudy        rain        19.972222                 19.972222
# 188532  Partly Cloudy        rain        17.816667                 17.816667
# 188533  Partly Cloudy        rain        13.938889                 13.938889
# 188534  Partly Cloudy        rain        12.733333                 12.733333
# 188535  Partly Cloudy        rain        13.038889                 13.038889
#
# ...

# %%
data
# Out:
#               Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0       Partly Cloudy        rain         9.472222                  7.388889
# 1       Partly Cloudy        rain         9.355556                  7.227778
# 2       Mostly Cloudy        rain         9.377778                  9.377778
# 3       Partly Cloudy        rain         8.288889                  5.944444
# 4       Mostly Cloudy        rain         8.755556                  6.977778
# ...               ...         ...              ...                       ...
# 188531  Partly Cloudy        rain        19.972222                 19.972222
# 188532  Partly Cloudy        rain        17.816667                 17.816667
# 188533  Partly Cloudy        rain        13.938889                 13.938889
# 188534  Partly Cloudy        rain        12.733333                 12.733333
# 188535  Partly Cloudy        rain        13.038889                 13.038889
#
# ...

# %%
data.sort_values(by='Temperature (C)', ascending=True)
# Out:
#               Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 149115          Foggy        snow       -21.822222                -21.822222
# 54847           Foggy        snow       -21.822222                -21.822222
# 55493           Foggy        snow       -21.111111                -21.111111
# 149758          Foggy        snow       -21.111111                -21.111111
# 55490           Foggy        snow       -21.111111                -21.111111
# ...               ...         ...              ...                       ...
# 12712   Partly Cloudy        rain        38.983333                 36.800000
# 107005  Partly Cloudy        rain        39.588889                 37.600000
# 12737   Partly Cloudy        rain        39.588889                 37.600000
# 12759           Clear        rain        39.905556                 37.538889
# 107027          Clear        rain        39.905556                 37.538889
#
# ...

# %%
k=sns.barplot(y=rain['month_name'],x=rain['Temperature (C)'],estimator=len)

# %%
sns.barplot(x='year',y='Summary',data=rain,estimator=len)
# Out:
# <Axes: xlabel='year', ylabel='Summary'>
